# %%
import stormpy
from graphviz import Source
from IPython.display import display

parsed = stormpy.parse_jani_model('/jani-models/DiningPhilosophers/phil4.jani')
model,_=parsed
dot_src=model.to_dot()
s = Source(dot_src, filename=".model.dot", format="png")

display(s)

# %%
import stormpy
from graphviz import Source
from IPython.display import display

parsed = stormpy.parse_jani_model('jani-models/DiningPhilosophers/phil4.jani')
model,_=parsed
dot_src=model.to_dot()
s = Source(dot_src, filename=".model.dot", format="png")

display(s)
